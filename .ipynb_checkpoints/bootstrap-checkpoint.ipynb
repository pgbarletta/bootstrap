# %%
using StatsBase
using DataFrames
using Gadfly

# %%
function tognm(vtor_anm)
    vtor_gnm = Array{Float64}(convert(Int64, length(vtor_anm)/3));
    vtor_anm =  vtor_anm.^2
    for i=1:convert(Int64, length(vtor_anm)/3)
        vtor_gnm[i] = sqrt(vtor_anm[i*3-2] + vtor_anm[i*3-1] + vtor_anm[i*3])
    end
    return vtor_gnm
end
# Out:
# tognm (generic function with 1 method)

# %%
function vtor_correl(vtor_input)
    # Preparo variables
    vtor_in = copy(vtor_input)
    vtor_in_corr = Array{Float64}(1);
    vtor_in_corr[1] = 5.0
    marca = length(vtor_in)
    
    for i=1:marca
        # Saco 2 vectores del vtor_input. A uno le saco el 1er elemento y a otro el último        
        vtor_in_prev = copy(vtor_input[1:end-i])
        shift!(vtor_in)
        # Obtengo correlacion entre los 2 vtores (autocorrelacion del vtor original) y determino
        # si es suficientemente alta como p/ seguir calculando correlacion
        corr = corspearman(vtor_in_prev, vtor_in)
        if corr < exp(-1)
            marca = copy(i)
            break
        end
        push!(vtor_in_corr, corr)
    end
    shift!(vtor_in_corr)
    # Devuelvo la secuencia de correlaciones q tuve y el nro de elementos q pude sacar antes de
    # q la correlación baje demasiado
    return vtor_in_corr, marca
end
# Out:
# vtor_correl (generic function with 1 method)

# %%
# Leo los vectores
modos = readdlm("/home/german/labo/16/bootstrap/1XKK_A_ord")
vec = modos[:, 300];

# Hago los indices p/ separar las coordenadas
xvec = vec[repeat([true, false, false], outer = [convert(Int64, length(vec)/3)])]
yvec = vec[repeat([false, true, false], outer = [convert(Int64, length(vec)/3)])]
zvec = vec[repeat([false, false, true], outer = [convert(Int64, length(vec)/3)])];

# Paso los vectores ANM a GNM
gvec = tognm(vec)

# Preparo variables
xvec_corr = Array{Float64}(length(xvec));
yvec_corr = Array{Float64}(length(yvec));
zvec_corr = Array{Float64}(length(zvec));
vec_corr = Array{Float64}(length(vec));

# %%
gvec_corr, block = vtor_correl(gvec)
# Out:
# (Float64[],1)

# %%
# Out:
# ([0.54979,0.548089,0.546165,0.546453,0.548694,0.54729,0.549309,0.550683,0.55077,0.550801  …  0.374056,0.405073,0.408362,0.406004,0.416802,0.405843,0.398056,0.398198,0.363305,0.34026],243)

# %%
df_vec_corr = DataFrame(corr = gvec_corr)
plot(df_vec_corr, y="corr", Geom.bar)
# Out:
# Plot(...)

# %%
gvec
# Out:
# 277-element Array{Float64,1}:
#  0.0532965
#  0.0559023
#  0.049475
#  0.0462906
#  0.039804
#  0.075261
#  0.0337309
#  0.0510229
#  0.0256555
#  0.028485
#  0.0278924
#  0.0383579
#  0.0221163
#  ⋮
#  0.029534
#  0.0455373
#  0.0244707
#  0.042669
#  0.032743
#  0.0854493
#  0.0368858
#  0.130088
#  0.0661759
#  0.0330457
#  0.0338182
#  0.072978

# %%
lasto = Int64
for i=1:length(vec)-3
    vec_prev = copy(vec[1:end-1])
    shift!(vec)
    vec_corr[i] = corspearman(vec_prev, vec)
    lasto = i
    if vec_corr[i] < exp(-1)
        break
    end
end

# %%
# Out:
# 258
